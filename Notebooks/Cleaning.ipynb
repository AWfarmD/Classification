# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime, date

# %%
df = pd.read_csv('Animal_Shelter_Intake_and_Outcome.csv')

# %%
df.head()
# Out:
#       Name Type              Breed        Color       Sex   Size  \
# 0     FIFI  CAT            SIAMESE      SEAL PT    Spayed  KITTN
# 1  *MERLIN  CAT        DOMESTIC SH    BRN TABBY  Neutered  SMALL
# 2    *ANDY  CAT        DOMESTIC SH        BLACK  Neutered  KITTN
# 3    *ANNE  CAT        DOMESTIC SH  BLACK/WHITE    Spayed  KITTN
# 4    RICKY  DOG  LABRADOR RETR/MIX   BLUE/WHITE  Neutered    MED
#
#   Date Of Birth Impound Number Kennel Number Animal ID  ...    Intake Subtype  \
# 0    10/27/2020     K21-037796          CA03   A402286  ...  OVER THE COUNTER
# 1    01/16/2018     K21-037709          CS05   A402139  ...             PHONE
# 2    09/06/2020     K20-037580      WESTFARM   A401875  ...             PHONE
# 3    09/06/2020     K20-037581      WESTFARM   A401876  ...             PHONE
# 4    01/04/2020     K21-037835          DS72   A402348  ...        FLD_ARREST
#
#       Outcome Type          Outcome Subtype Intake Condition  \
# ...

# %%
df.columns
# Out:
# Index(['Name', 'Type', 'Breed', 'Color', 'Sex', 'Size', 'Date Of Birth',
#        'Impound Number', 'Kennel Number', 'Animal ID', 'Intake Date',
#        'Outcome Date', 'Days in Shelter', 'Intake Type', 'Intake Subtype',
#        'Outcome Type', 'Outcome Subtype', 'Intake Condition',
#        'Outcome Condition', 'Intake Jurisdiction', 'Outcome Jurisdiction',
#        'Outcome Zip Code', 'Location', 'Count'],
#       dtype='object')

# %%
df.drop(['Impound Number', 'Animal ID', 'Intake Date', 'Intake Subtype', 
         'Outcome Subtype', 'Intake Condition', 'Intake Jurisdiction', 
         'Outcome Jurisdiction', 'Outcome Zip Code', 'Location', 'Count'],
        axis=1, inplace=True)

# %%
df.rename(columns = {'Name':'name',
                     'Type':'type',
                     'Breed':'breed',
                     'Color':'color',
                     'Sex':'sex',
                     'Size':'size',
                     'Date Of Birth':'dob',
                     'Kennel Number':'shelter',
                     'Outcome Date': 'outcome_date',
                     'Days in Shelter':'days_in_shelter',
                     'Intake Type':'intake_type',
                     'Outcome Type':'outcome',
                     'Outcome Condition':'outcome_condition'}, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21673 entries, 0 to 21672
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               16043 non-null  object
#  1   type               21673 non-null  object
#  2   breed              21673 non-null  object
#  3   color              21673 non-null  object
#  4   sex                21673 non-null  object
#  5   size               21641 non-null  object
#  6   dob                16362 non-null  object
#  7   shelter            21664 non-null  object
#  8   outcome_date       21512 non-null  object
#  9   days_in_shelter    21673 non-null  int64
#  10  intake_type        21673 non-null  object
#  11  outcome            21507 non-null  object
#  12  outcome_condition  21174 non-null  object
# dtypes: int64(1), object(12)
# memory usage: 2.1+ MB

# %%
df.dropna(subset=['size', 'dob', 'outcome_date', 'outcome', 'outcome_condition'], inplace=True)

# %%
df.name = df.name.fillna('no')

# %%
df.name = df.name.apply(lambda x: 'yes' if x != 'no' else x)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16104 entries, 0 to 21672
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               16104 non-null  object
#  1   type               16104 non-null  object
#  2   breed              16104 non-null  object
#  3   color              16104 non-null  object
#  4   sex                16104 non-null  object
#  5   size               16104 non-null  object
#  6   dob                16104 non-null  object
#  7   shelter            16104 non-null  object
#  8   outcome_date       16104 non-null  object
#  9   days_in_shelter    16104 non-null  int64
#  10  intake_type        16104 non-null  object
#  11  outcome            16104 non-null  object
#  12  outcome_condition  16104 non-null  object
# dtypes: int64(1), object(12)
# memory usage: 1.7+ MB

# %%
df.head()
# Out:
#   name type              breed        color       sex   size         dob  \
# 0  yes  CAT            SIAMESE      SEAL PT    Spayed  KITTN  10/27/2020
# 1  yes  CAT        DOMESTIC SH    BRN TABBY  Neutered  SMALL  01/16/2018
# 2  yes  CAT        DOMESTIC SH        BLACK  Neutered  KITTN  09/06/2020
# 3  yes  CAT        DOMESTIC SH  BLACK/WHITE    Spayed  KITTN  09/06/2020
# 4  yes  DOG  LABRADOR RETR/MIX   BLUE/WHITE  Neutered    MED  01/04/2020
#
#     shelter outcome_date  days_in_shelter      intake_type          outcome  \
# 0      CA03   02/05/2021                6  OWNER SURRENDER         ADOPTION
# 1      CS05   02/05/2021               20            STRAY         ADOPTION
# 2  WESTFARM   01/13/2021               18            STRAY         ADOPTION
# 3  WESTFARM   01/13/2021               18            STRAY         ADOPTION
# 4      DS72   02/05/2021                1       CONFISCATE  RETURN TO OWNER
#
#   outcome_condition
# 0           PENDING
# 1           PENDING
# ...

# %%
df.dob = pd.to_datetime(df.dob)

# %%
df.outcome_date = pd.to_datetime(df.outcome_date)

# %%
df['age'] = df.outcome_date - df.dob

# %%
df.drop(['dob'], axis=1, inplace=True)

# %%
df.head()
# Out:
#   name type              breed        color       sex   size   shelter  \
# 0  yes  CAT            SIAMESE      SEAL PT    Spayed  KITTN      CA03
# 1  yes  CAT        DOMESTIC SH    BRN TABBY  Neutered  SMALL      CS05
# 2  yes  CAT        DOMESTIC SH        BLACK  Neutered  KITTN  WESTFARM
# 3  yes  CAT        DOMESTIC SH  BLACK/WHITE    Spayed  KITTN  WESTFARM
# 4  yes  DOG  LABRADOR RETR/MIX   BLUE/WHITE  Neutered    MED      DS72
#
#   outcome_date  days_in_shelter      intake_type          outcome  \
# 0   2021-02-05                6  OWNER SURRENDER         ADOPTION
# 1   2021-02-05               20            STRAY         ADOPTION
# 2   2021-01-13               18            STRAY         ADOPTION
# 3   2021-01-13               18            STRAY         ADOPTION
# 4   2021-02-05                1       CONFISCATE  RETURN TO OWNER
#
#   outcome_condition       age
# 0           PENDING  101 days
# 1           PENDING 1116 days
# 2           HEALTHY  129 days
# ...

# %%
df.age = df.age.astype(str)

# %%
df.age = df.age.str.strip('days')

# %%
df.age = df.age.astype(int)

# %%
df.rename(columns = {'age':'age_in_days'}, inplace=True)

# %%
df.sex.unique()
# Out:
# array(['Spayed', 'Neutered', 'Female', 'Male', 'Unknown'], dtype=object)

# %%
drop_sex = df[df.sex == 'Unknown'].index

# %%
df.drop(drop_sex, inplace=True)

# %%
df.sex.unique()
# Out:
# array(['Spayed', 'Neutered', 'Female', 'Male'], dtype=object)

# %%
df.head()
# Out:
#   name type              breed        color       sex   size   shelter  \
# 0  yes  CAT            SIAMESE      SEAL PT    Spayed  KITTN      CA03
# 1  yes  CAT        DOMESTIC SH    BRN TABBY  Neutered  SMALL      CS05
# 2  yes  CAT        DOMESTIC SH        BLACK  Neutered  KITTN  WESTFARM
# 3  yes  CAT        DOMESTIC SH  BLACK/WHITE    Spayed  KITTN  WESTFARM
# 4  yes  DOG  LABRADOR RETR/MIX   BLUE/WHITE  Neutered    MED      DS72
#
#   outcome_date  days_in_shelter      intake_type          outcome  \
# 0   2021-02-05                6  OWNER SURRENDER         ADOPTION
# 1   2021-02-05               20            STRAY         ADOPTION
# 2   2021-01-13               18            STRAY         ADOPTION
# 3   2021-01-13               18            STRAY         ADOPTION
# 4   2021-02-05                1       CONFISCATE  RETURN TO OWNER
#
#   outcome_condition  age_in_days
# 0           PENDING          101
# 1           PENDING         1116
# 2           HEALTHY          129
# ...

# %%
df['outcome_day_of_week'] = df.outcome_date.dt.dayofweek

# %%
df.drop('outcome_date', axis=1, inplace=True)

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#       name type              breed             color       sex   size  \
# 0      yes  CAT            SIAMESE           SEAL PT    Spayed  KITTN
# 1      yes  CAT        DOMESTIC SH         BRN TABBY  Neutered  SMALL
# 2      yes  CAT        DOMESTIC SH             BLACK  Neutered  KITTN
# 3      yes  CAT        DOMESTIC SH       BLACK/WHITE    Spayed  KITTN
# 4      yes  DOG  LABRADOR RETR/MIX        BLUE/WHITE  Neutered    MED
# ...    ...  ...                ...               ...       ...    ...
# 15662  yes  DOG    AM PIT BULL TER  WHITE/BLUE MERLE      Male    MED
# 15663  yes  CAT        DOMESTIC SH         BRN TABBY    Spayed  KITTN
# 15664   no  DOG   CHIHUAHUA LH/MIX       BLACK/WHITE      Male    TOY
# 15665  yes  DOG   CHIHUAHUA LH/MIX       BROWN/WHITE  Neutered    TOY
# 15666   no  CAT        DOMESTIC SH            CALICO    Female  KITTN
#
#         shelter  days_in_shelter      intake_type          outcome  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15667 entries, 0 to 15666
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   name                 15667 non-null  object
#  1   type                 15667 non-null  object
#  2   breed                15667 non-null  object
#  3   color                15667 non-null  object
#  4   sex                  15667 non-null  object
#  5   size                 15667 non-null  object
#  6   shelter              15667 non-null  object
#  7   days_in_shelter      15667 non-null  int64
#  8   intake_type          15667 non-null  object
#  9   outcome              15667 non-null  object
#  10  outcome_condition    15667 non-null  object
#  11  age_in_days          15667 non-null  int64
#  12  outcome_day_of_week  15667 non-null  int64
# dtypes: int64(3), object(10)
# memory usage: 1.6+ MB

# %%
df.to_csv('adopt.csv', index=False)
